# %%
# Importing the Libraries
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the chosen files of data to work on
BR = pd.read_csv('/kaggle/input/youtube-trending-video-dataset/BR_youtube_trending_data.csv')
CA = pd.read_csv('/kaggle/input/youtube-trending-video-dataset/CA_youtube_trending_data.csv')
US = pd.read_csv('/kaggle/input/youtube-trending-video-dataset/US_youtube_trending_data.csv')

# %%
# Display the shape of each dataset
print(f'The shape of the BR Data is : {BR.shape}')
print(f'The shape of the CA Data is : {CA.shape}')
print(f'The shape of the US Data is : {US.shape}')
# Out:
# The shape of the BR Data is : (268790, 16)
# The shape of the CA Data is : (268742, 16)
# The shape of the US Data is : (268787, 16)

# %%
# Concatinate the data of all files together
all_data = pd.concat([BR,CA,US],axis=0)
all_data
# Out:
#            video_id                                              title  \
# 0       s9FH4rDMvds     LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1       jbGRowa5tIk                          ITZY “Not Shy” M/V TEASER
# 2       3EfkCrXKZNs                      Oh Juliana PARÓDIA - MC Niack
# 3       gBjox7vn3-g   Contos de Runeterra: Targon | A Estrada Tortuosa
# 4       npoUGx7UW7o  Entrevista com Thammy Miranda | The Noite (10/...
# ...             ...                                                ...
# 268782  4-uXvx5M7XA  Total solar eclipse causing tourism boost acro...
# 268783  aFsfJYWpqII  Food Delivery Apps: Last Week Tonight with Joh...
# 268784  pRAsQss17xs  12 Things NO-ONE Tells You About Japan | Feat....
# 268785  84QeCD7y_Ds                          Buying My Dream Car At 21
# 268786  SBTA3Tegacs                       Murder Drones Training Video
#
#                  publishedAt                 channelId  \
# 0       2020-08-11T22:21:49Z  UCGfBwrCoi9ZJjKiUK8MmJNw
# ...

# %%
# Checking the Information for the concatinated data "all_data"
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 806319 entries, 0 to 268786
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           806319 non-null  object
#  1   title              806319 non-null  object
#  2   publishedAt        806319 non-null  object
#  3   channelId          806319 non-null  object
#  4   channelTitle       806319 non-null  object
#  5   categoryId         806319 non-null  int64
#  6   trending_date      806319 non-null  object
#  7   tags               806319 non-null  object
#  8   view_count         806319 non-null  int64
#  9   likes              806319 non-null  int64
#  10  dislikes           806319 non-null  int64
#  11  comment_count      806319 non-null  int64
#  12  thumbnail_link     806319 non-null  object
#  13  comments_disabled  806319 non-null  bool
#  14  ratings_disabled   806319 non-null  bool
# ...

# %%
# This function is to checks if there is at least a comma within the text
# Then add double qoutes at the beginning and the end of the text if not exists
# To be used as text qualifier
def quote_if_needed(text):
    if not isinstance(text, str):
        return text  # Handle non-string values gracefully

    # Remove internal quotes
    text = text.replace('"', '')

    # If the text contains a comma, we may need to wrap it in quotes
    if ',' in text:
        if not text.startswith('"'):
            text = '"' + text
        if not text.endswith('"'):
            text = text + '"'
    return text

# %%
# This Cell Applies the function for all the features with object dtype 
# Select the object columns to apply
object_columns = BR.select_dtypes(include=['object']).columns

# apply the function to the selected columns
for col in object_columns:
    BR[col] = BR[col].apply(quote_if_needed)
    CA[col] = CA[col].apply(quote_if_needed)
    US[col] = US[col].apply(quote_if_needed)

# %%
# Saving a Fixed Version for each file to be used.
BR.to_csv('BR_Fixed.csv', index=False)
CA.to_csv('CA_Fixed.csv', index=False)
US.to_csv('US_Fixed.csv', index=False)
